# %% [markdown]
# # IMPORTS

# %%
import os

import pandas as pd

# %%
DO_FILL_NA = True
SET = "test"
DO_NAME_TSTEP_FIRST = False

# %%
RESULTS_MODEL_FOLDER = r"D:\OneDrive - fpts.com.vn\DucNN privates\Files\Codes\Khoa học dữ liệu\Luận văn tốt nghiệp Thạc sĩ Khoa học dữ liệu\QuantNet\Results_model"
RESULTS_BASELINE_FOLDER = r"D:\OneDrive - fpts.com.vn\DucNN privates\Files\Codes\Khoa học dữ liệu\Luận văn tốt nghiệp Thạc sĩ Khoa học dữ liệu\QuantNet\Results"

# %%
def get_results_summary(
    RESULTS_MODEL_FOLDER,
    mode="models",
    set="test",
):
    results_summary = pd.DataFrame(
        columns=[
            "region",
            "transferstrat",
            "non_zero_count",
            "valperiod",
            "testperiod",
            "train_steps",
            "tasksteps",
            "average_sharpe_ratio",
            "average_calmar_ratio",
            "average_maximum_draw_down",
            "average_annual_return",
            "average_volatility",
            "average_sortino_ratio",
            "average_down_risk",
            "average_value_at_risk",
            "average_tail_risk",
            "average_skew",
            "average_kurtosis",
        ]
    )
    csv_files = [f for f in os.listdir(RESULTS_MODEL_FOLDER) if f.endswith(".csv")]
    for i in range(len(csv_files)):
        file_name = csv_files[i]
        df = pd.read_csv(f"{RESULTS_MODEL_FOLDER}/{file_name}")
        if DO_FILL_NA:
            df = df.fillna(0)
        else:
            df = df[df["ANN_RET"] != 0]

        # Parse the file name to extract the relevant fields
        text = file_name.split("_")
        region = text[0]
        non_zero_count = len(df)
        valperiod = text[2]
        testperiod = text[4]
        if mode == "models":
            train_steps = text[6]
            tasksteps = text[8]
            if DO_NAME_TSTEP_FIRST:
                transferstrat = f"{int(train_steps):04d}_{file_name.split('_transferstrat_')[1].split('_lr')[0]}"
            else:
                transferstrat = f"{file_name.split('_transferstrat_')[1].split('_lr')[0]}_{int(train_steps):04d}"
        elif mode == "baseline":
            transferstrat = file_name.split("_baseline_")[1].split(".csv")[0]
            train_steps = None
            tasksteps = None
        else:
            raise ValueError(f"Invalid mode: {mode}")
        df_test = df[df["set"] == set]
        average_sharpe_ratio = df_test["SR"].mean()
        average_calmar_ratio = df_test["CR"].mean()
        average_maximum_draw_down = df_test["MDD"].mean()
        average_annual_return = df_test["ANN_RET"].mean()
        average_volatility = df_test["ANN_VOL"].mean()
        average_sortino_ratio = df_test["SortR"].mean()
        average_down_risk = df_test["DownRisk"].mean()
        average_value_at_risk = df_test["VaR"].mean()
        average_tail_risk = df_test["TailR"].mean()
        average_skew = df_test["Skew"].mean()
        average_kurtosis = df_test["Kurt"].mean()

        # Create a pandas Series with the extracted values
        meta_series = pd.Series(
            [
                region,
                transferstrat,
                non_zero_count,
                valperiod,
                testperiod,
                train_steps,
                tasksteps,
                average_sharpe_ratio,
                average_calmar_ratio,
                average_maximum_draw_down,
                average_annual_return,
                average_volatility,
                average_sortino_ratio,
                average_down_risk,
                average_value_at_risk,
                average_tail_risk,
                average_skew,
                average_kurtosis,
            ],
            index=[
                "region",
                "transferstrat",
                "non_zero_count",
                "valperiod",
                "testperiod",
                "train_steps",
                "tasksteps",
                "average_sharpe_ratio",
                "average_calmar_ratio",
                "average_maximum_draw_down",
                "average_annual_return",
                "average_volatility",
                "average_sortino_ratio",
                "average_down_risk",
                "average_value_at_risk",
                "average_tail_risk",
                "average_skew",
                "average_kurtosis",
            ],
        )

        # Append the Series as a new row to the results DataFrame
        results_summary = pd.concat(
            [results_summary, meta_series.to_frame().T], ignore_index=True
        )

    return results_summary

# %%
def get_results_grouped(results_summary):
    # Convert all columns except 'region' and 'transferstrat' to numeric
    cols_to_convert = [
        col for col in results_summary.columns if col not in ["region", "transferstrat"]
    ]
    cols_to_convert

    results_summary[cols_to_convert] = results_summary[cols_to_convert].apply(
        pd.to_numeric, errors="coerce"
    )
    results_summary_grouped = results_summary.groupby("transferstrat").mean(
        numeric_only=True
    )
    results_summary_grouped = results_summary_grouped.drop(
        columns=["valperiod", "testperiod", "train_steps", "tasksteps"]
    )
    return results_summary_grouped

# %%
results_summary_models = get_results_summary(
    RESULTS_MODEL_FOLDER,
    set=SET,
)
results_summary_models
# Out:
#        region              transferstrat non_zero_count valperiod testperiod  \
# 0    Americas  global_linear_linear_1000           3045         0        756
# 1    Americas    global_linear_lstm_1000           3045         0        756
# 2    Americas    global_lstm_linear_1000           3045         0        756
# 3    Americas      global_lstm_lstm_1000           3045         0        756
# 4    Americas    no_transfer_linear_1000           3045         0        756
# ..        ...                        ...            ...       ...        ...
# 127       MEA    global_linear_lstm_0500            933         0        756
# 128       MEA    global_lstm_linear_0500            933         0        756
# 129       MEA      global_lstm_lstm_0500            933         0        756
# 130       MEA    no_transfer_linear_0500            933         0        756
# 131       MEA      no_transfer_lstm_0500            933         0        756
#
#     train_steps tasksteps average_sharpe_ratio average_calmar_ratio  \
# 0          1000         0            -0.101629            -0.006249
# 1          1000         0             0.217888             0.279788
# 2          1000         0               0.2445             0.274472
# 3          1000         0              0.17429             0.206376
# 4          1000         0            -0.071531             0.116193
# ..          ...       ...                  ...                  ...
# 127         500         0             0.492639             0.728585
# 128         500         0              0.44487             0.681026
# 129         500         0              0.16116             0.187699
# 130         500         0              0.30084             0.545195
# 131         500         0             0.588865             0.840786
#
#     average_maximum_draw_down average_annual_return average_volatility  \
# 0                   -0.482689             -0.053714           0.313453
# 1                   -0.159673              0.030851            0.10718
# 2                   -0.125566              0.024097           0.087012
# 3                   -0.192877              0.023766           0.127997
# 4                    -0.01219              0.000285           0.006081
# ..                        ...                   ...                ...
# 127                 -0.132538              0.060151           0.099402
# 128                 -0.129458              0.055195           0.091184
# 129                 -0.188822              0.018543           0.120504
# 130                 -0.010735              0.003212           0.006868
# 131                 -0.046656              0.032076           0.037994
#
#     average_sortino_ratio average_down_risk average_value_at_risk  \
# 0                -0.09233          0.220728             -0.031768
# 1                0.367922           0.07493             -0.010047
# 2                0.423623          0.059515             -0.007409
# 3                0.293298          0.088051             -0.013297
# 4                0.001081          0.004238               -0.0005
# ..                    ...               ...                   ...
# 127               0.90838          0.065187             -0.008034
# 128              0.800996          0.060297             -0.007681
# 129              0.281303          0.081923             -0.011702
# 130              0.739369           0.00442             -0.000454
# 131              1.138466          0.023696             -0.002735
#
#     average_tail_risk average_skew average_kurtosis
# 0            0.985273     0.130796        16.377196
# 1            1.051022    -0.196955        23.456196
# 2            1.082012     0.108796        30.677008
# 3            1.020792     0.317431        16.041915
# 4            0.985653    -0.150128        33.338286
# ..                ...          ...              ...
# 127          1.211832     0.448467        23.790762
# 128          1.168529     0.351099        20.208769
# 129          1.060016     0.327277        12.841301
# 130          1.141454     0.565488        41.975886
# 131          1.232197     1.234993        32.587395
#
# [132 rows x 18 columns]

# %%
results_summary_baseline = get_results_summary(
    RESULTS_BASELINE_FOLDER,
    mode="baseline",
)
results_summary_baseline
# Out:
#               region           transferstrat non_zero_count valperiod  \
# 0           Americas            buy_and_hold           3045         0
# 1           Americas  buy_and_hold_shifted_1           3045         0
# 2           Americas                csec_mom           3045         0
# 3           Americas      csec_mom_shifted_1           3045         0
# 4           Americas             risk_parity           3045         0
# 5           Americas   risk_parity_shifted_1           3045         0
# 6           Americas                  ts_mom           3045         0
# 7           Americas        ts_mom_shifted_1           3045         0
# 8           Americas   risk_parity_shifted_1           2994       756
# 9   Asia and Pacific            buy_and_hold           3165         0
# 10  Asia and Pacific  buy_and_hold_shifted_1           3165         0
# 11  Asia and Pacific                csec_mom           3165         0
# 12  Asia and Pacific      csec_mom_shifted_1           3165         0
# 13  Asia and Pacific             risk_parity           3165         0
# 14  Asia and Pacific   risk_parity_shifted_1           3165         0
# 15  Asia and Pacific                  ts_mom           3165         0
# 16  Asia and Pacific        ts_mom_shifted_1           3165         0
# 17  Asia and Pacific   risk_parity_shifted_1           3165       756
# 18            Europe            buy_and_hold           1707         0
# 19            Europe  buy_and_hold_shifted_1           1707         0
# 20            Europe                csec_mom           1707         0
# 21            Europe      csec_mom_shifted_1           1707         0
# 22            Europe             risk_parity           1707         0
# 23            Europe   risk_parity_shifted_1           1707         0
# 24            Europe                  ts_mom           1707         0
# 25            Europe        ts_mom_shifted_1           1707         0
# 26            Europe   risk_parity_shifted_1           1707       756
# 27               MEA            buy_and_hold            933         0
# 28               MEA  buy_and_hold_shifted_1            933         0
# 29               MEA                csec_mom            933         0
# 30               MEA      csec_mom_shifted_1            933         0
# 31               MEA             risk_parity            933         0
# 32               MEA   risk_parity_shifted_1            933         0
# 33               MEA                  ts_mom            933         0
# 34               MEA        ts_mom_shifted_1            933         0
# 35               MEA   risk_parity_shifted_1            927       756
#
#    testperiod train_steps tasksteps average_sharpe_ratio average_calmar_ratio  \
# 0         756        None      None             0.183908             0.221635
# 1         756        None      None             0.183908             0.221635
# 2         756        None      None             0.156477             0.209499
# 3         756        None      None             0.158832             0.210131
# 4         756        None      None             0.202704             0.248655
# 5         756        None      None             0.179652              0.22651
# 6         756        None      None             0.169299             0.222664
# 7         756        None      None             0.176376             0.227859
# 8         756        None      None             0.316374             0.331909
# 9         756        None      None             0.153495             0.216378
# 10        756        None      None             0.153495             0.216378
# 11        756        None      None             0.158213             0.235102
# 12        756        None      None              0.13888             0.213223
# 13        756        None      None             0.189905             0.253763
# 14        756        None      None             0.188397             0.251738
# 15        756        None      None             0.145228             0.211822
# 16        756        None      None             0.125896             0.185736
# 17        756        None      None             0.182226             0.220156
# 18        756        None      None             0.341302             0.413665
# 19        756        None      None             0.341302             0.413665
# 20        756        None      None             0.073562             0.198998
# 21        756        None      None             0.042017             0.169306
# 22        756        None      None             0.340296             0.387843
# 23        756        None      None             0.339818              0.38943
# 24        756        None      None             0.059651             0.205559
# 25        756        None      None             0.030989              0.17362
# 26        756        None      None             0.292432             0.353306
# 27        756        None      None             0.186314             0.223281
# 28        756        None      None             0.186314             0.223281
# 29        756        None      None             0.106794              0.22479
# 30        756        None      None             0.083761             0.208626
# 31        756        None      None             0.176077             0.241094
# 32        756        None      None             0.176698                0.243
# 33        756        None      None             0.076775             0.187545
# 34        756        None      None               0.0529              0.16033
# 35        756        None      None             0.077518             0.199211
#
#    average_maximum_draw_down average_annual_return average_volatility  \
# 0                  -0.002932              0.001503            0.00203
# 1                  -0.002932              0.001503            0.00203
# 2                  -0.007819             -0.000959           0.003255
# 3                  -0.007782             -0.000915           0.003251
# 4                  -0.002739              0.001507           0.001919
# 5                  -0.002764              0.001488           0.001919
# 6                  -0.007378             -0.000971           0.002905
# 7                  -0.007331             -0.000942           0.002903
# 8                  -0.367154              0.083155           0.268292
# 9                  -0.006277              0.000393           0.003533
# 10                 -0.006277              0.000393           0.003533
# 11                 -0.011474             -0.000099           0.005767
# 12                  -0.01137             -0.000154           0.005742
# 13                 -0.005769               0.00041           0.003236
# 14                 -0.005784              0.000412           0.003245
# 15                 -0.009982             -0.000085           0.005036
# 16                  -0.00993             -0.000169           0.005019
# 17                 -0.368482              0.045335           0.264787
# 18                 -0.020836               0.00426           0.013939
# 19                 -0.020836               0.00426           0.013939
# 20                 -0.039574             -0.000624           0.024127
# 21                 -0.039635             -0.000196            0.02385
# 22                 -0.020319              0.003469           0.012527
# 23                 -0.020334               0.00349           0.012546
# 24                 -0.034775             -0.000353           0.021078
# 25                 -0.034668              0.000159           0.020826
# 26                 -0.363666              0.080245           0.275972
# 27                 -0.020936              0.003579           0.012813
# 28                 -0.020936              0.003579           0.012813
# 29                 -0.043313             -0.000917           0.021402
# 30                 -0.042762             -0.001272           0.021291
# 31                 -0.021315              0.003556           0.012914
# 32                 -0.021317              0.003615            0.01294
# 33                 -0.038288             -0.001256           0.018646
# 34                 -0.037971             -0.001566           0.018592
# 35                 -0.395872              0.025353           0.263442
#
#    average_sortino_ratio average_down_risk average_value_at_risk  \
# 0               0.305422          0.001336             -0.000198
# 1               0.305422          0.001336             -0.000198
# 2               0.314023          0.002252             -0.000308
# 3               0.316536          0.002243             -0.000308
# 4               0.343701          0.001268             -0.000183
# 5               0.307766          0.001269             -0.000183
# 6               0.320548          0.002014             -0.000269
# 7                0.33026          0.002009             -0.000268
# 8               0.616117            0.1876             -0.024643
# 9                0.26937          0.002382             -0.000341
# 10               0.26937          0.002382             -0.000341
# 11              0.321764          0.003966             -0.000491
# 12              0.284979          0.003943             -0.000491
# 13              0.329738          0.002189             -0.000304
# 14              0.328594          0.002194             -0.000304
# 15              0.273769          0.003478             -0.000427
# 16              0.239742           0.00346             -0.000428
# 17              0.454521          0.175233              -0.02408
# 18              0.649616          0.009079             -0.001159
# 19              0.649616          0.009079             -0.001159
# 20              0.232516          0.015059             -0.001675
# 21              0.179257          0.014768             -0.001686
# 22              0.580987          0.008848             -0.001115
# 23              0.580745          0.008857             -0.001117
# 24               0.19613          0.013163             -0.001444
# 25              0.148823           0.01284             -0.001448
# 26              0.591248          0.189109             -0.024332
# 27              0.323795          0.008562             -0.001212
# 28              0.323795          0.008562             -0.001212
# 29              0.270311          0.014574             -0.001642
# 30              0.243092          0.014478             -0.001648
# 31              0.328066          0.008655             -0.001191
# 32              0.330026          0.008667             -0.001191
# 33              0.196812          0.012756             -0.001508
# 34              0.157814          0.012696             -0.001512
# 35              0.300231          0.179081             -0.024412
#
#    average_tail_risk average_skew average_kurtosis
# 0           1.019992     0.330703        16.015522
# 1           1.019992     0.330703        16.015522
# 2           0.996571     0.878188        28.979839
# 3           0.999598     0.855134        28.311037
# 4           1.041968     0.269512        21.235993
# 5           1.035076     0.248183        20.744926
# 6           0.997753     0.772736        24.526062
# 7           0.998024     0.751611         23.99143
# 8           1.009938    -0.145227        14.312348
# 9           1.040065      0.59505        12.890531
# 10          1.040065      0.59505        12.890531
# 11          1.013274     0.644586        31.113139
# 12          1.012182     0.661787        29.887685
# 13          1.063274     0.653773         16.63144
# 14          1.062682     0.674841         16.67481
# 15          1.011031     0.425617        22.666916
# 16           1.01014     0.423588        21.818634
# 17          1.082326     0.615214        12.349547
# 18          1.049673    -0.072954        25.666133
# 19          1.049673    -0.072954        25.666133
# 20          1.001697     0.790773        35.388953
# 21          0.991582     0.780725        35.089359
# 22          1.052346    -0.161957        28.475354
# 23           1.05157    -0.162993        28.488318
# 24          1.003131     0.584224        28.217475
# 25          0.996123     0.582915        28.134369
# 26          1.073519     -0.07589        16.347804
# 27          1.077302     0.370954        12.772222
# 28          1.077302     0.370954        12.772222
# 29           0.98711      0.99333         34.37877
# 30          0.979311     1.007852        33.609452
# 31          1.084686     0.389506        17.741427
# 32          1.085388     0.392487        17.832909
# 33          0.983368     0.732116        26.191487
# 34          0.977568     0.731612        25.707903
# 35          1.080198     0.239565        15.330554

# %%
results_summary_models_grouped = get_results_grouped(results_summary_models)
results_summary_models_grouped
# Out:
#                            non_zero_count  average_sharpe_ratio  \
# transferstrat
# global_linear_linear_0500          2212.5              0.169057
# global_linear_linear_1000          2212.5              0.170856
# global_linear_linear_2000          2212.5              0.187600
# global_linear_lstm_0500            2212.5              0.314366
# global_linear_lstm_1000            2212.5              0.357383
# global_linear_lstm_2000            2212.5              0.207020
# global_lstm_linear_0500            2212.5              0.308456
# global_lstm_linear_1000            2212.5              0.302436
# global_lstm_linear_2000            2212.5              0.270568
# global_lstm_lstm_0500              2212.5              0.191651
# global_lstm_lstm_1000              2212.5              0.186056
# global_lstm_lstm_2000              2212.5              0.185881
# no_transfer_linear_0500            2212.5              0.140000
# no_transfer_linear_1000            2212.5              0.140946
# no_transfer_linear_2000            2212.5              0.143088
# no_transfer_lstm_0500              2212.5              0.261903
# no_transfer_lstm_1000              2212.5              0.187294
# no_transfer_lstm_2000              2212.5              0.244161
#
#                            average_calmar_ratio  average_maximum_draw_down  \
# transferstrat
# global_linear_linear_0500              0.281897                  -0.420413
# global_linear_linear_1000              0.277225                  -0.419514
# global_linear_linear_2000              0.259181                  -0.426812
# global_linear_lstm_0500                0.411143                  -0.163591
# global_linear_lstm_1000                0.452747                  -0.166332
# global_linear_lstm_2000                0.286080                  -0.197095
# global_lstm_linear_0500                0.443682                  -0.157859
# global_lstm_linear_1000                0.442598                  -0.134453
# global_lstm_linear_2000                0.369094                  -0.141262
# global_lstm_lstm_0500                  0.237449                  -0.195200
# global_lstm_lstm_1000                  0.236020                  -0.188262
# global_lstm_lstm_2000                  0.233056                  -0.186942
# no_transfer_linear_0500                0.301372                  -0.011277
# no_transfer_linear_1000                0.309391                  -0.010509
# no_transfer_linear_2000                0.312582                  -0.011096
# no_transfer_lstm_0500                  0.396177                  -0.118426
# no_transfer_lstm_1000                  0.292803                  -0.135570
# no_transfer_lstm_2000                  0.363837                  -0.114426
#
#                            average_annual_return  average_volatility  \
# transferstrat
# global_linear_linear_0500               0.033623            0.299146
# global_linear_linear_1000               0.036175            0.304022
# global_linear_linear_2000               0.034281            0.307897
# global_linear_lstm_0500                 0.034771            0.110929
# global_linear_lstm_1000                 0.045979            0.113734
# global_linear_lstm_2000                 0.022833            0.122523
# global_lstm_linear_0500                 0.037954            0.105516
# global_lstm_linear_1000                 0.033103            0.090284
# global_lstm_linear_2000                 0.028572            0.091511
# global_lstm_lstm_0500                   0.024800            0.130368
# global_lstm_lstm_1000                   0.026057            0.125901
# global_lstm_lstm_2000                   0.024102            0.125532
# no_transfer_linear_0500                 0.001705            0.006569
# no_transfer_linear_1000                 0.001307            0.005968
# no_transfer_linear_2000                 0.001337            0.006257
# no_transfer_lstm_0500                   0.017601            0.073607
# no_transfer_lstm_1000                   0.012035            0.083321
# no_transfer_lstm_2000                   0.016162            0.070347
#
#                            average_sortino_ratio  average_down_risk  \
# transferstrat
# global_linear_linear_0500               0.341947           0.203296
# global_linear_linear_1000               0.336716           0.205852
# global_linear_linear_2000               0.358027           0.209330
# global_linear_lstm_0500                 0.572023           0.075354
# global_linear_lstm_1000                 0.627825           0.077521
# global_linear_lstm_2000                 0.385288           0.084813
# global_lstm_linear_0500                 0.579938           0.070262
# global_lstm_linear_1000                 0.594182           0.060567
# global_lstm_linear_2000                 0.525349           0.062407
# global_lstm_lstm_0500                   0.347553           0.087499
# global_lstm_lstm_1000                   0.338437           0.084389
# global_lstm_lstm_2000                   0.337715           0.083512
# no_transfer_linear_0500                 0.369745           0.004379
# no_transfer_linear_1000                 0.367301           0.003993
# no_transfer_linear_2000                 0.368049           0.004203
# no_transfer_lstm_0500                   0.518833           0.050400
# no_transfer_lstm_1000                   0.369350           0.057967
# no_transfer_lstm_2000                   0.459713           0.048455
#
#                            average_value_at_risk  average_tail_risk  \
# transferstrat
# global_linear_linear_0500              -0.027776           1.041003
# global_linear_linear_1000              -0.028330           1.041795
# global_linear_linear_2000              -0.028671           1.044089
# global_linear_lstm_0500                -0.009829           1.094243
# global_linear_lstm_1000                -0.009891           1.098516
# global_linear_lstm_2000                -0.011053           1.062761
# global_lstm_linear_0500                -0.009429           1.088869
# global_lstm_linear_1000                -0.007317           1.094079
# global_lstm_linear_2000                -0.007692           1.082749
# global_lstm_lstm_0500                  -0.012867           1.041707
# global_lstm_lstm_1000                  -0.012402           1.042099
# global_lstm_lstm_2000                  -0.012235           1.040735
# no_transfer_linear_0500                -0.000468           1.057284
# no_transfer_linear_1000                -0.000415           1.063061
# no_transfer_linear_2000                -0.000439           1.065629
# no_transfer_lstm_0500                  -0.006719           1.082626
# no_transfer_lstm_1000                  -0.007597           1.073856
# no_transfer_lstm_2000                  -0.006227           1.082220
#
#                            average_skew  average_kurtosis
# transferstrat
# global_linear_linear_0500      0.120775         17.252990
# global_linear_linear_1000      0.181831         17.407433
# global_linear_linear_2000      0.135554         17.067326
# global_linear_lstm_0500        0.122484         22.846018
# global_linear_lstm_1000        0.095361         24.479196
# global_linear_lstm_2000        0.019801         23.649569
# global_lstm_linear_0500        0.254249         23.025901
# global_lstm_linear_1000        0.230263         33.618744
# global_lstm_linear_2000        0.150216         30.527257
# global_lstm_lstm_0500          0.291124         17.381717
# global_lstm_lstm_1000          0.284230         17.096867
# global_lstm_lstm_2000          0.230011         16.994206
# no_transfer_linear_0500        0.275279         42.820704
# no_transfer_linear_1000        0.314870         43.973577
# no_transfer_linear_2000        0.300490         44.268576
# no_transfer_lstm_0500          0.349986         29.303463
# no_transfer_lstm_1000          0.131776         28.243050
# no_transfer_lstm_2000          0.168423         28.866218

# %%
results_summary_baseline_grouped = get_results_grouped(
    results_summary=results_summary_baseline
)
results_summary_baseline_grouped
# Out:
#                         non_zero_count  average_sharpe_ratio  \
# transferstrat
# buy_and_hold                  2212.500              0.216255
# buy_and_hold_shifted_1        2212.500              0.216255
# csec_mom                      2212.500              0.123761
# csec_mom_shifted_1            2212.500              0.105873
# risk_parity                   2212.500              0.227245
# risk_parity_shifted_1         2205.375              0.219139
# ts_mom                        2212.500              0.112738
# ts_mom_shifted_1              2212.500              0.096540
#
#                         average_calmar_ratio  average_maximum_draw_down  \
# transferstrat
# buy_and_hold                        0.268740                  -0.012745
# buy_and_hold_shifted_1              0.268740                  -0.012745
# csec_mom                            0.217097                  -0.025545
# csec_mom_shifted_1                  0.200321                  -0.025387
# risk_parity                         0.282839                  -0.012536
# risk_parity_shifted_1               0.276908                  -0.193172
# ts_mom                              0.206898                  -0.022606
# ts_mom_shifted_1                    0.186886                  -0.022475
#
#                         average_annual_return  average_volatility  \
# transferstrat
# buy_and_hold                         0.002434            0.008079
# buy_and_hold_shifted_1               0.002434            0.008079
# csec_mom                            -0.000650            0.013638
# csec_mom_shifted_1                  -0.000634            0.013533
# risk_parity                          0.002235            0.007649
# risk_parity_shifted_1                0.030387            0.137893
# ts_mom                              -0.000666            0.011916
# ts_mom_shifted_1                    -0.000630            0.011835
#
#                         average_sortino_ratio  average_down_risk  \
# transferstrat
# buy_and_hold                         0.387051           0.005340
# buy_and_hold_shifted_1               0.387051           0.005340
# csec_mom                             0.284653           0.008963
# csec_mom_shifted_1                   0.255966           0.008858
# risk_parity                          0.395623           0.005240
# risk_parity_shifted_1                0.438656           0.094001
# ts_mom                               0.246815           0.007853
# ts_mom_shifted_1                     0.219160           0.007751
#
#                         average_value_at_risk  average_tail_risk  \
# transferstrat
# buy_and_hold                        -0.000728           1.046758
# buy_and_hold_shifted_1              -0.000728           1.046758
# csec_mom                            -0.001029           0.999663
# csec_mom_shifted_1                  -0.001033           0.995668
# risk_parity                         -0.000698           1.060568
# risk_parity_shifted_1               -0.012533           1.060087
# ts_mom                              -0.000912           0.998821
# ts_mom_shifted_1                    -0.000914           0.995464
#
#                         average_skew  average_kurtosis
# transferstrat
# buy_and_hold                0.305938         16.836102
# buy_and_hold_shifted_1      0.305938         16.836102
# csec_mom                    0.826719         32.465175
# csec_mom_shifted_1          0.826375         31.724383
# risk_parity                 0.287708         21.021054
# risk_parity_shifted_1       0.223273         17.760152
# ts_mom                      0.628673         25.400485
# ts_mom_shifted_1            0.622432         24.913084

# %%
results_grouped = pd.concat(
    [results_summary_models_grouped, results_summary_baseline_grouped]
)
results_grouped
# Out:
#                            non_zero_count  average_sharpe_ratio  \
# transferstrat
# global_linear_linear_0500        2212.500              0.169057
# global_linear_linear_1000        2212.500              0.170856
# global_linear_linear_2000        2212.500              0.187600
# global_linear_lstm_0500          2212.500              0.314366
# global_linear_lstm_1000          2212.500              0.357383
# global_linear_lstm_2000          2212.500              0.207020
# global_lstm_linear_0500          2212.500              0.308456
# global_lstm_linear_1000          2212.500              0.302436
# global_lstm_linear_2000          2212.500              0.270568
# global_lstm_lstm_0500            2212.500              0.191651
# global_lstm_lstm_1000            2212.500              0.186056
# global_lstm_lstm_2000            2212.500              0.185881
# no_transfer_linear_0500          2212.500              0.140000
# no_transfer_linear_1000          2212.500              0.140946
# no_transfer_linear_2000          2212.500              0.143088
# no_transfer_lstm_0500            2212.500              0.261903
# no_transfer_lstm_1000            2212.500              0.187294
# no_transfer_lstm_2000            2212.500              0.244161
# buy_and_hold                     2212.500              0.216255
# buy_and_hold_shifted_1           2212.500              0.216255
# csec_mom                         2212.500              0.123761
# csec_mom_shifted_1               2212.500              0.105873
# risk_parity                      2212.500              0.227245
# risk_parity_shifted_1            2205.375              0.219139
# ts_mom                           2212.500              0.112738
# ts_mom_shifted_1                 2212.500              0.096540
#
#                            average_calmar_ratio  average_maximum_draw_down  \
# transferstrat
# global_linear_linear_0500              0.281897                  -0.420413
# global_linear_linear_1000              0.277225                  -0.419514
# global_linear_linear_2000              0.259181                  -0.426812
# global_linear_lstm_0500                0.411143                  -0.163591
# global_linear_lstm_1000                0.452747                  -0.166332
# global_linear_lstm_2000                0.286080                  -0.197095
# global_lstm_linear_0500                0.443682                  -0.157859
# global_lstm_linear_1000                0.442598                  -0.134453
# global_lstm_linear_2000                0.369094                  -0.141262
# global_lstm_lstm_0500                  0.237449                  -0.195200
# global_lstm_lstm_1000                  0.236020                  -0.188262
# global_lstm_lstm_2000                  0.233056                  -0.186942
# no_transfer_linear_0500                0.301372                  -0.011277
# no_transfer_linear_1000                0.309391                  -0.010509
# no_transfer_linear_2000                0.312582                  -0.011096
# no_transfer_lstm_0500                  0.396177                  -0.118426
# no_transfer_lstm_1000                  0.292803                  -0.135570
# no_transfer_lstm_2000                  0.363837                  -0.114426
# buy_and_hold                           0.268740                  -0.012745
# buy_and_hold_shifted_1                 0.268740                  -0.012745
# csec_mom                               0.217097                  -0.025545
# csec_mom_shifted_1                     0.200321                  -0.025387
# risk_parity                            0.282839                  -0.012536
# risk_parity_shifted_1                  0.276908                  -0.193172
# ts_mom                                 0.206898                  -0.022606
# ts_mom_shifted_1                       0.186886                  -0.022475
#
#                            average_annual_return  average_volatility  \
# transferstrat
# global_linear_linear_0500               0.033623            0.299146
# global_linear_linear_1000               0.036175            0.304022
# global_linear_linear_2000               0.034281            0.307897
# global_linear_lstm_0500                 0.034771            0.110929
# global_linear_lstm_1000                 0.045979            0.113734
# global_linear_lstm_2000                 0.022833            0.122523
# global_lstm_linear_0500                 0.037954            0.105516
# global_lstm_linear_1000                 0.033103            0.090284
# global_lstm_linear_2000                 0.028572            0.091511
# global_lstm_lstm_0500                   0.024800            0.130368
# global_lstm_lstm_1000                   0.026057            0.125901
# global_lstm_lstm_2000                   0.024102            0.125532
# no_transfer_linear_0500                 0.001705            0.006569
# no_transfer_linear_1000                 0.001307            0.005968
# no_transfer_linear_2000                 0.001337            0.006257
# no_transfer_lstm_0500                   0.017601            0.073607
# no_transfer_lstm_1000                   0.012035            0.083321
# no_transfer_lstm_2000                   0.016162            0.070347
# buy_and_hold                            0.002434            0.008079
# buy_and_hold_shifted_1                  0.002434            0.008079
# csec_mom                               -0.000650            0.013638
# csec_mom_shifted_1                     -0.000634            0.013533
# risk_parity                             0.002235            0.007649
# risk_parity_shifted_1                   0.030387            0.137893
# ts_mom                                 -0.000666            0.011916
# ts_mom_shifted_1                       -0.000630            0.011835
#
#                            average_sortino_ratio  average_down_risk  \
# transferstrat
# global_linear_linear_0500               0.341947           0.203296
# global_linear_linear_1000               0.336716           0.205852
# global_linear_linear_2000               0.358027           0.209330
# global_linear_lstm_0500                 0.572023           0.075354
# global_linear_lstm_1000                 0.627825           0.077521
# global_linear_lstm_2000                 0.385288           0.084813
# global_lstm_linear_0500                 0.579938           0.070262
# global_lstm_linear_1000                 0.594182           0.060567
# global_lstm_linear_2000                 0.525349           0.062407
# global_lstm_lstm_0500                   0.347553           0.087499
# global_lstm_lstm_1000                   0.338437           0.084389
# global_lstm_lstm_2000                   0.337715           0.083512
# no_transfer_linear_0500                 0.369745           0.004379
# no_transfer_linear_1000                 0.367301           0.003993
# no_transfer_linear_2000                 0.368049           0.004203
# no_transfer_lstm_0500                   0.518833           0.050400
# no_transfer_lstm_1000                   0.369350           0.057967
# no_transfer_lstm_2000                   0.459713           0.048455
# buy_and_hold                            0.387051           0.005340
# buy_and_hold_shifted_1                  0.387051           0.005340
# csec_mom                                0.284653           0.008963
# csec_mom_shifted_1                      0.255966           0.008858
# risk_parity                             0.395623           0.005240
# risk_parity_shifted_1                   0.438656           0.094001
# ts_mom                                  0.246815           0.007853
# ts_mom_shifted_1                        0.219160           0.007751
#
#                            average_value_at_risk  average_tail_risk  \
# transferstrat
# global_linear_linear_0500              -0.027776           1.041003
# global_linear_linear_1000              -0.028330           1.041795
# global_linear_linear_2000              -0.028671           1.044089
# global_linear_lstm_0500                -0.009829           1.094243
# global_linear_lstm_1000                -0.009891           1.098516
# global_linear_lstm_2000                -0.011053           1.062761
# global_lstm_linear_0500                -0.009429           1.088869
# global_lstm_linear_1000                -0.007317           1.094079
# global_lstm_linear_2000                -0.007692           1.082749
# global_lstm_lstm_0500                  -0.012867           1.041707
# global_lstm_lstm_1000                  -0.012402           1.042099
# global_lstm_lstm_2000                  -0.012235           1.040735
# no_transfer_linear_0500                -0.000468           1.057284
# no_transfer_linear_1000                -0.000415           1.063061
# no_transfer_linear_2000                -0.000439           1.065629
# no_transfer_lstm_0500                  -0.006719           1.082626
# no_transfer_lstm_1000                  -0.007597           1.073856
# no_transfer_lstm_2000                  -0.006227           1.082220
# buy_and_hold                           -0.000728           1.046758
# buy_and_hold_shifted_1                 -0.000728           1.046758
# csec_mom                               -0.001029           0.999663
# csec_mom_shifted_1                     -0.001033           0.995668
# risk_parity                            -0.000698           1.060568
# risk_parity_shifted_1                  -0.012533           1.060087
# ts_mom                                 -0.000912           0.998821
# ts_mom_shifted_1                       -0.000914           0.995464
#
#                            average_skew  average_kurtosis
# transferstrat
# global_linear_linear_0500      0.120775         17.252990
# global_linear_linear_1000      0.181831         17.407433
# global_linear_linear_2000      0.135554         17.067326
# global_linear_lstm_0500        0.122484         22.846018
# global_linear_lstm_1000        0.095361         24.479196
# global_linear_lstm_2000        0.019801         23.649569
# global_lstm_linear_0500        0.254249         23.025901
# global_lstm_linear_1000        0.230263         33.618744
# global_lstm_linear_2000        0.150216         30.527257
# global_lstm_lstm_0500          0.291124         17.381717
# global_lstm_lstm_1000          0.284230         17.096867
# global_lstm_lstm_2000          0.230011         16.994206
# no_transfer_linear_0500        0.275279         42.820704
# no_transfer_linear_1000        0.314870         43.973577
# no_transfer_linear_2000        0.300490         44.268576
# no_transfer_lstm_0500          0.349986         29.303463
# no_transfer_lstm_1000          0.131776         28.243050
# no_transfer_lstm_2000          0.168423         28.866218
# buy_and_hold                   0.305938         16.836102
# buy_and_hold_shifted_1         0.305938         16.836102
# csec_mom                       0.826719         32.465175
# csec_mom_shifted_1             0.826375         31.724383
# risk_parity                    0.287708         21.021054
# risk_parity_shifted_1          0.223273         17.760152
# ts_mom                         0.628673         25.400485
# ts_mom_shifted_1               0.622432         24.913084

# %% [markdown]
# # Averages

# %%
results_grouped_filtered = results_grouped[
    ~results_grouped.index.str.contains("_shifted_1")
]

# %%
import matplotlib.pyplot as plt

metrics = [
    "average_sharpe_ratio",
    "average_calmar_ratio",
    "average_maximum_draw_down",
    "average_annual_return",
    "average_volatility",
    "average_sortino_ratio",
    "average_down_risk",
    "average_value_at_risk",
    "average_tail_risk",
    "average_skew",
    "average_kurtosis",
]

for metric in metrics:
    plt.figure(figsize=(10, 6))
    results_grouped_filtered[metric].plot(kind="bar")
    plt.title(f"{metric.replace('_', ' ').title()} by Strategy")
    plt.ylabel(metric.replace("_", " ").title())
    plt.xlabel("Strategy")
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Ranked metrics

# %%
results_grouped_rank = results_grouped.copy()
positive_rank_metrics = [
    "average_sharpe_ratio",
    "average_calmar_ratio",
    "average_annual_return",
    "average_sortino_ratio",
]

for metric in positive_rank_metrics:
    results_grouped_rank[metric] = results_grouped_rank[metric].rank(
        ascending=False, method="min"
    )

negative_rank_metrics = [
    "average_maximum_draw_down",
    "average_volatility",
    "average_down_risk",
    "average_value_at_risk",
    "average_tail_risk",
]

rank_metrics = positive_rank_metrics + negative_rank_metrics
for metric in negative_rank_metrics:
    results_grouped_rank[metric] = results_grouped_rank[metric].rank(
        ascending=True, method="min"
    )

results_grouped_rank = results_grouped_rank[rank_metrics]
results_grouped_rank
# Out:
#                            average_sharpe_ratio  average_calmar_ratio  \
# transferstrat
# global_linear_linear_0500                  19.0                  14.0
# global_linear_linear_1000                  18.0                  15.0
# global_linear_linear_2000                  14.0                  19.0
# global_linear_lstm_0500                     2.0                   4.0
# global_linear_lstm_1000                     1.0                   1.0
# global_linear_lstm_2000                    12.0                  12.0
# global_lstm_linear_0500                     3.0                   2.0
# global_lstm_linear_1000                     4.0                   3.0
# global_lstm_linear_2000                     5.0                   6.0
# global_lstm_lstm_0500                      13.0                  20.0
# global_lstm_lstm_1000                      16.0                  21.0
# global_lstm_lstm_2000                      17.0                  22.0
# no_transfer_linear_0500                    22.0                  10.0
# no_transfer_linear_1000                    21.0                   9.0
# no_transfer_linear_2000                    20.0                   8.0
# no_transfer_lstm_0500                       6.0                   5.0
# no_transfer_lstm_1000                      15.0                  11.0
# no_transfer_lstm_2000                       7.0                   7.0
# buy_and_hold                               10.0                  17.0
# buy_and_hold_shifted_1                     10.0                  17.0
# csec_mom                                   23.0                  23.0
# csec_mom_shifted_1                         25.0                  25.0
# risk_parity                                 8.0                  13.0
# risk_parity_shifted_1                       9.0                  16.0
# ts_mom                                     24.0                  24.0
# ts_mom_shifted_1                           26.0                  26.0
#
#                            average_annual_return  average_sortino_ratio  \
# transferstrat
# global_linear_linear_0500                    6.0                   19.0
# global_linear_linear_1000                    3.0                   22.0
# global_linear_linear_2000                    5.0                   17.0
# global_linear_lstm_0500                      4.0                    4.0
# global_linear_lstm_1000                      1.0                    1.0
# global_linear_lstm_2000                     13.0                   12.0
# global_lstm_linear_0500                      2.0                    3.0
# global_lstm_linear_1000                      7.0                    2.0
# global_lstm_linear_2000                      9.0                    5.0
# global_lstm_lstm_0500                       11.0                   18.0
# global_lstm_lstm_1000                       10.0                   20.0
# global_lstm_lstm_2000                       12.0                   21.0
# no_transfer_linear_0500                     20.0                   13.0
# no_transfer_linear_1000                     22.0                   16.0
# no_transfer_linear_2000                     21.0                   15.0
# no_transfer_lstm_0500                       14.0                    6.0
# no_transfer_lstm_1000                       16.0                   14.0
# no_transfer_lstm_2000                       15.0                    7.0
# buy_and_hold                                17.0                   10.0
# buy_and_hold_shifted_1                      17.0                   10.0
# csec_mom                                    25.0                   23.0
# csec_mom_shifted_1                          24.0                   24.0
# risk_parity                                 19.0                    9.0
# risk_parity_shifted_1                        8.0                    8.0
# ts_mom                                      26.0                   25.0
# ts_mom_shifted_1                            23.0                   26.0
#
#                            average_maximum_draw_down  average_volatility  \
# transferstrat
# global_linear_linear_0500                        2.0                24.0
# global_linear_linear_1000                        3.0                25.0
# global_linear_linear_2000                        1.0                26.0
# global_linear_lstm_0500                         10.0                17.0
# global_linear_lstm_1000                          9.0                18.0
# global_linear_lstm_2000                          4.0                19.0
# global_lstm_linear_0500                         11.0                16.0
# global_lstm_linear_1000                         14.0                14.0
# global_lstm_linear_2000                         12.0                15.0
# global_lstm_lstm_0500                            5.0                22.0
# global_lstm_lstm_1000                            7.0                21.0
# global_lstm_lstm_2000                            8.0                20.0
# no_transfer_linear_0500                         24.0                 3.0
# no_transfer_linear_1000                         26.0                 1.0
# no_transfer_linear_2000                         25.0                 2.0
# no_transfer_lstm_0500                           15.0                12.0
# no_transfer_lstm_1000                           13.0                13.0
# no_transfer_lstm_2000                           16.0                11.0
# buy_and_hold                                    21.0                 5.0
# buy_and_hold_shifted_1                          21.0                 5.0
# csec_mom                                        17.0                10.0
# csec_mom_shifted_1                              18.0                 9.0
# risk_parity                                     23.0                 4.0
# risk_parity_shifted_1                            6.0                23.0
# ts_mom                                          19.0                 8.0
# ts_mom_shifted_1                                20.0                 7.0
#
#                            average_down_risk  average_value_at_risk  \
# transferstrat
# global_linear_linear_0500               24.0                    3.0
# global_linear_linear_1000               25.0                    2.0
# global_linear_linear_2000               26.0                    1.0
# global_linear_lstm_0500                 17.0                   10.0
# global_linear_lstm_1000                 18.0                    9.0
# global_linear_lstm_2000                 21.0                    8.0
# global_lstm_linear_0500                 16.0                   11.0
# global_lstm_linear_1000                 14.0                   14.0
# global_lstm_linear_2000                 15.0                   12.0
# global_lstm_lstm_0500                   22.0                    4.0
# global_lstm_lstm_1000                   20.0                    6.0
# global_lstm_lstm_2000                   19.0                    7.0
# no_transfer_linear_0500                  3.0                   24.0
# no_transfer_linear_1000                  1.0                   26.0
# no_transfer_linear_2000                  2.0                   25.0
# no_transfer_lstm_0500                   12.0                   15.0
# no_transfer_lstm_1000                   13.0                   13.0
# no_transfer_lstm_2000                   11.0                   16.0
# buy_and_hold                             5.0                   21.0
# buy_and_hold_shifted_1                   5.0                   21.0
# csec_mom                                10.0                   18.0
# csec_mom_shifted_1                       9.0                   17.0
# risk_parity                              4.0                   23.0
# risk_parity_shifted_1                   23.0                    5.0
# ts_mom                                   8.0                   20.0
# ts_mom_shifted_1                         7.0                   19.0
#
#                            average_tail_risk
# transferstrat
# global_linear_linear_0500                6.0
# global_linear_linear_1000                8.0
# global_linear_linear_2000               10.0
# global_linear_lstm_0500                 25.0
# global_linear_lstm_1000                 26.0
# global_linear_lstm_2000                 16.0
# global_lstm_linear_0500                 23.0
# global_lstm_linear_1000                 24.0
# global_lstm_linear_2000                 22.0
# global_lstm_lstm_0500                    7.0
# global_lstm_lstm_1000                    9.0
# global_lstm_lstm_2000                    5.0
# no_transfer_linear_0500                 13.0
# no_transfer_linear_1000                 17.0
# no_transfer_linear_2000                 18.0
# no_transfer_lstm_0500                   21.0
# no_transfer_lstm_1000                   19.0
# no_transfer_lstm_2000                   20.0
# buy_and_hold                            11.0
# buy_and_hold_shifted_1                  11.0
# csec_mom                                 4.0
# csec_mom_shifted_1                       2.0
# risk_parity                             15.0
# risk_parity_shifted_1                   14.0
# ts_mom                                   3.0
# ts_mom_shifted_1                         1.0

# %%
results_grouped_rank_total = results_grouped_rank.sum(axis=1)
results_grouped_rank_total
# Out:
# transferstrat
# global_linear_linear_0500    117.0
# global_linear_linear_1000    121.0
# global_linear_linear_2000    119.0
# global_linear_lstm_0500       93.0
# global_linear_lstm_1000       84.0
# global_linear_lstm_2000      117.0
# global_lstm_linear_0500       87.0
# global_lstm_linear_1000       96.0
# global_lstm_linear_2000      101.0
# global_lstm_lstm_0500        122.0
# global_lstm_lstm_1000        130.0
# global_lstm_lstm_2000        131.0
# no_transfer_linear_0500      132.0
# no_transfer_linear_1000      139.0
# no_transfer_linear_2000      136.0
# no_transfer_lstm_0500        106.0
# no_transfer_lstm_1000        127.0
# no_transfer_lstm_2000        110.0
# buy_and_hold                 117.0
# buy_and_hold_shifted_1       117.0
# csec_mom                     153.0
# csec_mom_shifted_1           153.0
# risk_parity                  118.0
# risk_parity_shifted_1        112.0
# ts_mom                       157.0
# ts_mom_shifted_1             155.0
# dtype: float64

# %%
for metric in rank_metrics:
    plt.figure(figsize=(10, 6))
    results_grouped_rank[metric].plot(kind="bar")
    plt.title(f"Ranked {metric.replace('_', ' ').title()} by Strategy")
    plt.ylabel(metric.replace("_", " ").title())
    plt.xlabel("Strategy")
    plt.xticks(rotation=45, ha="right")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Total rank

# %%
results_grouped_rank_total.plot(kind="bar")
plt.title("Total Rank by Strategy")
plt.ylabel("Total Rank")
plt.xlabel("Strategy")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
